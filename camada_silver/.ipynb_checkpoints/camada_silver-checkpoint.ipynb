# %%
import pandas as pd
from sqlalchemy import create_engine

def obter_dados_tabela(tabela, conn_str):
    """
    Obtém dados de uma tabela no banco de dados e retorna um DataFrame.
    
    Parameters:
        nome_tabela (str): O nome da tabela a ser consultada.
        conn_str (str): A string de conexão do SQLAlchemy para o banco de dados.

    Returns:
        pd.DataFrame: Um DataFrame contendo os dados da tabela.
    """
    engine = create_engine(conn_str)
    consulta_sql = f"SELECT * FROM {tabela}"
    df = pd.read_sql_query(consulta_sql, engine)
    return df

conn_str = "postgresql://postgres:postgres@localhost:5432/postgres"

listings_df = obter_dados_tabela("listings", conn_str)
reviews_df = obter_dados_tabela("reviews", conn_str)
calendar_df = obter_dados_tabela("calendar", conn_str)

# %%
import pandas as pd
from ydata_profiling import ProfileReport

class DataCleaner:
    @staticmethod
    def remove_duplicates(df):
        return df.drop_duplicates()

    @staticmethod
    def remove_constant(df):
        list_constant = [col for col in df.columns if df[col].nunique() == 1]
        return df.drop(columns=list_constant)

    @staticmethod
    def verify_unbalanced(df):
        list_imbalance = []
        limit = 0.98
        for col in df.columns:
            counts = df[col].value_counts(normalize=True)
            if len(counts) >= 2:
                perc = counts.values[0]
                if perc > limit:
                    list_imbalance.append(col)
                    print(col, perc)
        return list_imbalance

    @staticmethod
    def remove_unbalanced(df):
        list_imbalance = DataCleaner.verify_unbalanced(df)
        return df.drop(list_imbalance, axis=1)

    @staticmethod
    def generate_report(df, title, minimal=True):
        df = DataCleaner.remove_duplicates(df)
        df = DataCleaner.remove_constant(df)
        df = DataCleaner.remove_unbalanced(df)
        report = ProfileReport(df, title=title, minimal=minimal)
        return (df, report)

# %% [markdown]
# ## CALENDAR

# %%
(cleaned_calendar_df, calendar_report) = DataCleaner.generate_report(calendar_df, title="Relatório de Dados: Calendar", minimal=True)
calendar_report.to_file("treated_calendar_report.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
def transform_calendar(df):
    # Converte 'listing_id' para int
    df['listing_id'] = df['listing_id'].astype(int)
    
    # Converte 'minimum_nights' e 'maximum_nights' para int
    df['minimum_nights'] = df['minimum_nights'].fillna(0).astype(int)
    df['maximum_nights'] = df['maximum_nights'].fillna(0).astype(int)
    
    # Remove vírgulas e o símbolo '$' e, em seguida, converte para float
    df['price'] = df['price'].str.replace(',', '', regex=False).str.replace('$', '', regex=False).astype(float)
    df['adjusted_price'] = df['adjusted_price'].str.replace(',', '', regex=False).str.replace('$', '', regex=False).astype(float)
    
    # Converte 'date' para o tipo de data
    df['date'] = pd.to_datetime(df['date'])
    
    # Substituir 't' por 'Sim' e 'f' por 'Não' na coluna 'available'
    df['available'] = df['available'].replace({'t': 'Sim', 'f': 'Não'})

  
    return df

# %%
calendar_transfor = transform_calendar(cleaned_calendar_df)

# %% [markdown]
# ## LISTINGS

# %% [markdown]
# ### Tratamento e transformação de campos

# %%
import re

def transform_listings(df):
    df['description'] = df['description'].apply(lambda x: re.sub(r'[^a-zA-Z0-9]', ' ', x).lower() if isinstance(x, str) else x)
    
    integer_columns = [
    'id', 'host_id', 'host_listings_count', 'host_total_listings_count',
    'accommodates', 'bedrooms', 'bathrooms', 'beds', 'minimum_nights', 'maximum_nights',
    'minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights',
    'maximum_maximum_nights', 'availability_30', 'availability_60', 'availability_90',
    'availability_365', 'number_of_reviews', 'number_of_reviews_ltm',
    'number_of_reviews_l30d', 'calculated_host_listings_count',
    'calculated_host_listings_count_entire_homes',
    'calculated_host_listings_count_private_rooms',
    'calculated_host_listings_count_shared_rooms'
    ]

    for column in integer_columns:
        df[column] = pd.to_numeric(df[column], errors='coerce').fillna(0).astype(int)
        
    boolean_columns = ['host_is_superhost', 'host_identity_verified', 'has_availability', 'instant_bookable']
    df[boolean_columns] = df[boolean_columns].replace({'t': True, 'f': False}).astype(bool)
        
    return df

# %% [markdown]
# ### Preenchimento de valores faltantes
#
# #### - "no_info" para campos de texto - porque não há como substituir a informação;
# #### - -1 para campos de score - porque fica fora do intervalo de score, podendo ser facilmente filtrado, sem afetar o tipo das colunas;
# #### - 0 para bedrooms - porque, sem um número de quartos, pressupõe-se nenhum.

# %%
def check_miss(df):
        df_miss = df.isna().sum()
        df_miss = (df_miss / len(df)) * 100
        df_miss = df_miss.sort_values(ascending=False)
        for col in df_miss.index:
            if str(df[col].dtypes) == "object":
                df[col] = df[col].fillna("no_info")
            if str(df[col].dtypes) == "float64":
                df[col] = df[col].fillna(float(-1))
        return df

# %%
listings_transfor = transform_listings(listings_df)
listings_without_missing_values = check_miss(listings_transfor)
(cleaned_listings_df, treated_report_listings) = DataCleaner.generate_report(listings_without_missing_values, title="Relatório de Dados: Listings", minimal=True)
#treated_report_listings.to_file("treated_report_listings.html")
# Out:
# calculated_host_listings_count_shared_rooms 0.989

# %% [markdown]
# ### Eliminação de Outliers

# %%
description = listings_transfor.describe()
column_names_description = description.columns.tolist()
columns_to_exclude = ['id', 'scrape_id', 'host_id']
column_names_description = [col for col in column_names_description if col not in columns_to_exclude]

# %%
listings_aux = listings_transfor.copy()
print("Quantidade de linhas antes de eliminar os outliers:", len(listings_transfor))
low_limit = listings_aux['reviews_per_month'].quantile(.01)
high_limit = listings_aux['reviews_per_month'].quantile(.99)
listings_transfor = listings_transfor[(listings_transfor['reviews_per_month']>low_limit) & (listings_transfor['reviews_per_month']<high_limit)]
print("Quantidade de linhas depois de eliminar os outliers:", len(listings_transfor))
# Out:
# Quantidade de linhas antes de eliminar os outliers: 1000
# Quantidade de linhas depois de eliminar os outliers: 893

# %%
print("Quantidade de linhas antes de eliminar os outliers:", len(listings_transfor))
listings_aux = listings_transfor.copy()
for col in column_names_description:
    low_limit = listings_aux[col].quantile(.01)
    high_limit = listings_aux[col].quantile(.99)
    listings_transfor = listings_transfor[(listings_transfor[col]>low_limit) & (listings_transfor[col]<high_limit)] #filtra a partir do quantil

print("Quantidade de linhas depois de eliminar os outliers:", len(listings_transfor))
# Out:
# Quantidade de linhas antes de eliminar os outliers: 893
# Quantidade de linhas depois de eliminar os outliers: 0

# %% [markdown]
# ## REVIEWS

# %% [markdown]
# ### Tratamento e transformação de campos

# %%
def transform_reviews(df):
    # Renomeando coluna 'id' para 'review_id'
    df = df.rename(columns={'id':'review_id'})
    
    # Converte 'listing_id', 'review_id', 'reviewer_id' para inteiros
    df['listing_id'] = df['listing_id'].astype(int)
    df['review_id'] = df['review_id'].astype(int)
    df['reviewer_id'] = df['reviewer_id'].astype(int)
    
    # Converte 'date' para o tipo de data
    df['date'] = pd.to_datetime(df['date'])
    
    # Limpa a coluna 'reviewer_name'
    df['reviewer_name'] = df['reviewer_name'].str.replace('[^a-zA-Z ]', '', regex=True)
    df['reviewer_name'] = df['reviewer_name'].str.title()
    
    # Limpa a coluna 'comments'
    df['comments'] = df['comments'].str.replace('[^a-zA-Z0-9,;.\s]', '', regex=True)
    df['comments'] = df['comments'].str.replace(r'<[^>]+>|[\\\/][^ ]+', '', regex=True)
    
    return df

# %%
reviews_transfor = transform_reviews(reviews_df)
(cleaned_reviews_df, reviews_report) = DataCleaner.generate_report(reviews_transfor, title="Relatório de Dados: reviews", minimal=True)
reviews_report.to_file("treated_reviews_report.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
boolean_columns = [
    'host_is_superhost', 'host_identity_verified', 'has_availability', 'instant_bookable'
]

for col in boolean_columns:
    print(cleaned_listings_df[col])
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999     True
# Name: host_is_superhost, Length: 1000, dtype: bool
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 995    True
# 996    True
# 997    True
# 998    True
# 999    True
# Name: host_identity_verified, Length: 1000, dtype: bool
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 995     True
# 996     True
# 997     True
# 998     True
# 999     True
# Name: has_availability, Length: 1000, dtype: bool
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: instant_bookable, Length: 1000, dtype: bool

# %% [markdown]
# # Great Expectations

# %%
import great_expectations as gx

gx_listings = gx.from_pandas(cleaned_listings_df)
display(gx_listings)
# Out:
#           id                           listing_url last_scraped       source  \
# 0     231497   https://www.airbnb.com/rooms/231497   2023-09-22  city scrape
# 1     231516   https://www.airbnb.com/rooms/231516   2023-09-22  city scrape
# 2     236991   https://www.airbnb.com/rooms/236991   2023-09-23  city scrape
# 3      17878    https://www.airbnb.com/rooms/17878   2023-09-23  city scrape
# 4     900709   https://www.airbnb.com/rooms/900709   2023-09-22  city scrape
# ..       ...                                   ...          ...          ...
# 995  2283224  https://www.airbnb.com/rooms/2283224   2023-09-22  city scrape
# 996  2130431  https://www.airbnb.com/rooms/2130431   2023-09-22  city scrape
# 997  2283279  https://www.airbnb.com/rooms/2283279   2023-09-22  city scrape
# 998  2283286  https://www.airbnb.com/rooms/2283286   2023-09-22  city scrape
# 999  2132605  https://www.airbnb.com/rooms/2132605   2023-09-23  city scrape
#
#                                                   name  \
# 0    Rental unit in Rio de Janeiro · ★4.73 · 1 bedr...
# 1    Rental unit in Rio de Janeiro · ★4.71 · 1 bedr...
# 2    Rental unit in Rio de Janeiro · ★4.89 · 1 bedr...
# 3    Condo in Rio de Janeiro · ★4.70 · 2 bedrooms ·...
# 4    Rental unit in Rio de Janeiro · 1 bedroom · 1 ...
# ..                                                 ...
# 995  Condo in Barra da Tijuca · 1 bedroom · 2 beds ...
# 996  Rental unit in Rio · ★4.76 · 2 bedrooms · 5 be...
# 997  Rental unit in Rio · ★4.44 · 1 bedroom · 3 bed...
# 998  Rental unit in Rio · ★5.0 · 1 bedroom · 2 beds...
# 999   Loft in Rio · ★4.77 · 1 bedroom · 1 bed · 1 bath
#
#                                            description  \
# 0    this is a big studio at the end of copacabana ...
# 1    special location of the building  on copacaban...
# 2    aconchegante  amplo  b sico  arejado  iluminad...
# 3    please note that elevated rates applies for ne...
# 4    gorgeous apt 2 rooms 1 bedroom kitchen  bathro...
# ..                                                 ...
# 995  flat na praia da barra da tijuca  apartamentos...
# 996  this boutique apartment belongs to a brazilian...
# 997  nosso lugar   um silencioso apartamento de 1 q...
# 998  localizado no posto 3  h  2 quadras da praia d...
# 999  chic   design 60 sqm loft in ipanema with pano...
#
#                                  neighborhood_overview  \
# 0                                              no_info
# 1                                              no_info
# 2    Copacabana, apelidada a princesinha do mar, fa...
# 3    This is the one of the bests spots in Rio. Bec...
# 4                                              no_info
# ..                                                 ...
# 995                                            no_info
# 996  Leblon (Alto and Baixo Leblon)<br />Upper Lebl...
# 997  Vizinhança discreta e hospitaleira, com muitas...
# 998                                            no_info
# 999  The apartment is 5 minutes walk to Plaça Gener...
#
#                                            picture_url   host_id  \
# 0    https://a0.muscache.com/pictures/3582382/ee8ac...   1207700
# 1    https://a0.muscache.com/pictures/3671683/d74b4...   1207700
# 2    https://a0.muscache.com/pictures/5725a59b-147d...   1241662
# 3    https://a0.muscache.com/pictures/65320518/3069...     68997
# 4    https://a0.muscache.com/pictures/13585778/f2f2...   2649464
# ..                                                 ...       ...
# 995  https://a0.muscache.com/pictures/78dbdb2c-0071...    513685
# 996  https://a0.muscache.com/pictures/35008067/36a6...  10869099
# 997  https://a0.muscache.com/pictures/31688307/a9e3...    713884
# 998  https://a0.muscache.com/pictures/7d2ce37f-3736...  11661949
# 999  https://a0.muscache.com/pictures/miso/Hosting-...  10881674
#
#                                        host_url  ...  \
# 0     https://www.airbnb.com/users/show/1207700  ...
# 1     https://www.airbnb.com/users/show/1207700  ...
# 2     https://www.airbnb.com/users/show/1241662  ...
# 3       https://www.airbnb.com/users/show/68997  ...
# 4     https://www.airbnb.com/users/show/2649464  ...
# ..                                          ...  ...
# 995    https://www.airbnb.com/users/show/513685  ...
# 996  https://www.airbnb.com/users/show/10869099  ...
# 997    https://www.airbnb.com/users/show/713884  ...
# 998  https://www.airbnb.com/users/show/11661949  ...
# 999  https://www.airbnb.com/users/show/10881674  ...
#
#     review_scores_cleanliness review_scores_checkin  \
# 0                        4.86                  4.89
# 1                        4.52                  4.79
# 2                        4.91                  4.97
# 3                        4.64                  4.83
# 4                       -1.00                 -1.00
# ..                        ...                   ...
# 995                      5.00                  5.00
# 996                      4.78                  4.89
# 997                      4.58                  4.53
# 998                      5.00                  5.00
# 999                      4.83                  4.81
#
#     review_scores_communication review_scores_location review_scores_value  \
# 0                          4.92                   4.90                4.65
# 1                          4.86                   4.93                4.38
# 2                          4.96                   4.99                4.89
# 3                          4.91                   4.77                4.67
# 4                         -1.00                  -1.00               -1.00
# ..                          ...                    ...                 ...
# 995                        5.00                   5.00                5.00
# 996                        4.97                   4.79                4.28
# 997                        4.45                   4.84                4.37
# 998                        5.00                   4.60                4.80
# 999                        4.82                   4.33                4.65
#
#     instant_bookable calculated_host_listings_count  \
# 0                  f                              4
# 1                  f                              4
# 2                  f                              2
# 3                  f                              1
# 4                  f                              1
# ..               ...                            ...
# 995                f                              9
# 996                f                              1
# 997                f                              1
# 998                f                              2
# 999                f                              1
#
#     calculated_host_listings_count_entire_homes  \
# 0                                             4
# 1                                             4
# 2                                             2
# 3                                             1
# 4                                             1
# ..                                          ...
# 995                                           7
# 996                                           1
# 997                                           1
# 998                                           2
# 999                                           1
#
#     calculated_host_listings_count_private_rooms reviews_per_month
# 0                                              0              0.54
# 1                                              0              0.20
# 2                                              0              0.65
# 3                                              0              1.87
# 4                                              0             -1.00
# ..                                           ...               ...
# 995                                            2              0.11
# 996                                            0              0.26
# 997                                            0              0.36
# 998                                            0              0.06
# 999                                            0              0.97
#
# [1000 rows x 68 columns]

# %%
integer_columns = [
    'id', 'host_id', 'host_listings_count', 'host_total_listings_count',
    'accommodates', 'bedrooms', 'beds', 'minimum_nights', 'maximum_nights',
    'minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights',
    'maximum_maximum_nights', 'availability_30', 'availability_60', 'availability_90',
    'availability_365', 'number_of_reviews', 'number_of_reviews_ltm',
    'number_of_reviews_l30d', 'calculated_host_listings_count',
    'calculated_host_listings_count_entire_homes',
    'calculated_host_listings_count_private_rooms'
]
text_columns = [
    'listing_url', 'source', 'name', 'description', 'neighborhood_overview',
    'picture_url', 'host_url', 'host_name', 'host_location', 'host_about',
    'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood', 'neighbourhood',
    'neighbourhood_cleansed', 'property_type', 'room_type'
]
float_columns = [
    'review_scores_rating', 'review_scores_accuracy',
    'review_scores_cleanliness', 'review_scores_checkin',
    'review_scores_communication', 'review_scores_location', 'review_scores_value',
    'reviews_per_month'
]
boolean_columns = [
    'host_is_superhost', 'host_identity_verified', 'has_availability', 'instant_bookable'
]

# %%
for column in integer_columns:
    gx_listings.expect_column_values_to_be_of_type(column=column, type_='int64')

gx_listings.get_expectation_suite()
# Out:
# {
#   "expectation_suite_name": "default",
#   "ge_cloud_id": null,
#   "expectations": [
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "id",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "host_id",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "host_listings_count",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "host_total_listings_count",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "accommodates",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "bedrooms",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "beds",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "minimum_nights",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "maximum_nights",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "minimum_minimum_nights",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "maximum_minimum_nights",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "minimum_maximum_nights",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "maximum_maximum_nights",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "availability_30",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "availability_60",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "availability_90",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "availability_365",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "number_of_reviews",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "number_of_reviews_ltm",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "number_of_reviews_l30d",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "calculated_host_listings_count",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "calculated_host_listings_count_entire_homes",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "calculated_host_listings_count_private_rooms",
#         "type_": "int64"
#       },
#       "meta": {}
#     }
#   ],
#   "data_asset_type": "Dataset",
#   "meta": {
#     "great_expectations_version": "0.17.23"
#   }
# }

# %%
for column in float_columns:
    gx_listings.expect_column_values_to_be_of_type(column=column, type_='float64')

gx_listings.get_expectation_suite()
# Out:
# {
#   "expectation_suite_name": "default",
#   "ge_cloud_id": null,
#   "expectations": [
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "id",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "host_id",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "host_listings_count",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "host_total_listings_count",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "accommodates",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "bedrooms",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "beds",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "minimum_nights",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "maximum_nights",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "minimum_minimum_nights",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "maximum_minimum_nights",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "minimum_maximum_nights",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "maximum_maximum_nights",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "availability_30",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "availability_60",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "availability_90",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "availability_365",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "number_of_reviews",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "number_of_reviews_ltm",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "number_of_reviews_l30d",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "calculated_host_listings_count",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "calculated_host_listings_count_entire_homes",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "calculated_host_listings_count_private_rooms",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "review_scores_rating",
#         "type_": "float64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "review_scores_accuracy",
#         "type_": "float64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "review_scores_cleanliness",
#         "type_": "float64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "review_scores_checkin",
#         "type_": "float64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "review_scores_communication",
#         "type_": "float64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "review_scores_location",
#         "type_": "float64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "review_scores_value",
#         "type_": "float64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "reviews_per_month",
#         "type_": "float64"
#       },
#       "meta": {}
#     }
#   ],
#   "data_asset_type": "Dataset",
#   "meta": {
#     "great_expectations_version": "0.17.23"
#   }
# }

# %%
for column in text_columns:
    gx_listings.expect_column_values_to_be_of_type(column=column, type_='object')

gx_listings.get_expectation_suite()
# Out:
# {
#   "expectation_suite_name": "default",
#   "ge_cloud_id": null,
#   "expectations": [
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "id",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "host_id",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "host_listings_count",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "host_total_listings_count",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "accommodates",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "bedrooms",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "beds",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "minimum_nights",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "maximum_nights",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "minimum_minimum_nights",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "maximum_minimum_nights",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "minimum_maximum_nights",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "maximum_maximum_nights",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "availability_30",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "availability_60",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "availability_90",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "availability_365",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "number_of_reviews",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "number_of_reviews_ltm",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "number_of_reviews_l30d",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "calculated_host_listings_count",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "calculated_host_listings_count_entire_homes",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "calculated_host_listings_count_private_rooms",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "review_scores_rating",
#         "type_": "float64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "review_scores_accuracy",
#         "type_": "float64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "review_scores_cleanliness",
#         "type_": "float64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "review_scores_checkin",
#         "type_": "float64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "review_scores_communication",
#         "type_": "float64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "review_scores_location",
#         "type_": "float64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "review_scores_value",
#         "type_": "float64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "reviews_per_month",
#         "type_": "float64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "listing_url",
#         "type_": "object"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "source",
#         "type_": "object"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "name",
#         "type_": "object"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "description",
#         "type_": "object"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "neighborhood_overview",
#         "type_": "object"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "picture_url",
#         "type_": "object"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "host_url",
#         "type_": "object"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "host_name",
#         "type_": "object"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "host_location",
#         "type_": "object"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "host_about",
#         "type_": "object"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "host_thumbnail_url",
#         "type_": "object"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "host_picture_url",
#         "type_": "object"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "host_neighbourhood",
#         "type_": "object"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "neighbourhood",
#         "type_": "object"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "neighbourhood_cleansed",
#         "type_": "object"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "property_type",
#         "type_": "object"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "room_type",
#         "type_": "object"
#       },
#       "meta": {}
#     }
#   ],
#   "data_asset_type": "Dataset",
#   "meta": {
#     "great_expectations_version": "0.17.23"
#   }
# }

# %%
for column in boolean_columns:
    gx_listings.expect_column_values_to_be_of_type(column=column, type_='bool')

gx_listings.get_expectation_suite()
# Out:
# {
#   "expectation_suite_name": "default",
#   "ge_cloud_id": null,
#   "expectations": [
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "id",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "host_id",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "host_listings_count",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "host_total_listings_count",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "accommodates",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "bedrooms",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "beds",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "minimum_nights",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "maximum_nights",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "minimum_minimum_nights",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "maximum_minimum_nights",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "minimum_maximum_nights",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "maximum_maximum_nights",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "availability_30",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "availability_60",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "availability_90",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "availability_365",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "number_of_reviews",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "number_of_reviews_ltm",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "number_of_reviews_l30d",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "calculated_host_listings_count",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "calculated_host_listings_count_entire_homes",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "calculated_host_listings_count_private_rooms",
#         "type_": "int64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "review_scores_rating",
#         "type_": "float64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "review_scores_accuracy",
#         "type_": "float64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "review_scores_cleanliness",
#         "type_": "float64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "review_scores_checkin",
#         "type_": "float64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "review_scores_communication",
#         "type_": "float64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "review_scores_location",
#         "type_": "float64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "review_scores_value",
#         "type_": "float64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "reviews_per_month",
#         "type_": "float64"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "listing_url",
#         "type_": "object"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "source",
#         "type_": "object"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "name",
#         "type_": "object"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "description",
#         "type_": "object"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "neighborhood_overview",
#         "type_": "object"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "picture_url",
#         "type_": "object"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "host_url",
#         "type_": "object"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "host_name",
#         "type_": "object"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "host_location",
#         "type_": "object"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "host_about",
#         "type_": "object"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "host_thumbnail_url",
#         "type_": "object"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "host_picture_url",
#         "type_": "object"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "host_neighbourhood",
#         "type_": "object"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "neighbourhood",
#         "type_": "object"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "neighbourhood_cleansed",
#         "type_": "object"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "property_type",
#         "type_": "object"
#       },
#       "meta": {}
#     },
#     {
#       "expectation_type": "expect_column_values_to_be_of_type",
#       "kwargs": {
#         "column": "room_type",
#         "type_": "object"
#       },
#       "meta": {}
#     }
#   ],
#   "data_asset_type": "Dataset",
#   "meta": {
#     "great_expectations_version": "0.17.23"
#   }
# }
